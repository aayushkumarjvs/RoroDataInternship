# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\hp\\Desktop\\saxpy-master\\saxpy-master\\jupyter'

# %%
os.chdir("C:\\Users\\hp\\Desktop\\sax_pro")
import numpy as np
from saxpy.znorm import znorm
from saxpy.discord import find_discords_brute_force

# %%
from numpy import genfromtxt
dd = genfromtxt("C:\\Users\\hp\\Desktop\\sinwave\\swdg.csv", delimiter=',')

# %%
import matplotlib.pyplot as plt
plt.plot(dd)
plt.show()

# %%
discords = find_discords_brute_force(dd[0:400], 100, 4)
discords
# Out:
# [(0, inf), (171, 0.6282151815625662), (273, 0.0)]

# %%
import matplotlib.pyplot as plt
plt.plot(discords)
plt.show()

# %%
discords[0][0]
# Out:
# 0

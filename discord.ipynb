# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\Admin\\Desktop\\rorodata_study\\saxpy-master\\jupyter'

# %%
os.chdir("C:\\Users\\Admin\\Desktop\\sax_pro")
import numpy as np
from saxpy.znorm import znorm
from saxpy.discord import find_discords_brute_force

# %%
from numpy import genfromtxt
dd = genfromtxt("C:\\Users\\Admin\\Desktop\\street-lighting-86a4d-ultrasonic-export.csv", delimiter=',')    

##dd = genfromtxt("C:\\Users\\Admin\\Desktop\\##street-lighting-86a4d-ldr-export.csv", delimiter=',')

# %%
import matplotlib.pyplot as plt
plt.plot(dd)
plt.show()

# %%
discords = find_discords_brute_force(dd[0:400], 100, 4)
discords
# Out:
# [(0, inf), (112, 14.001932442278436), (219, 10.991524531989345)]

# %%
discords[0][0]
# Out:
# 0

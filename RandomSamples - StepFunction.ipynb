# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\hp\\Desktop\\sax_pro'

# %%
os.chdir("C:\\Users\\hp\\Desktop\\sax_pro")
import numpy as np
from saxpy.znorm import znorm
from saxpy.discord import find_discords_brute_force

# %%
from numpy import genfromtxt
dd = genfromtxt("C:\\Users\\hp\\Desktop\\test-driven-data\\Sweep\\SweepOneToTwoPointFive.csv", delimiter=',')

# %%
import matplotlib.pyplot as plt
plt.plot(dd)
plt.show()

# %%
discords = find_discords_brute_force(dd[0:400], 100, 4)
discords
# Out:
# [(299, 0.46237584881375965), (100, 0.22190168591755252)]

# %%
import matplotlib.pyplot as plt
plt.plot(discords)
plt.show()

# %%
discords[0][0]
# Out:
# 299

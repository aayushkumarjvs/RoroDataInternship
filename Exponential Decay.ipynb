# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\hp\\Desktop\\saxpy-master\\saxpy-master\\jupyter'

# %%
os.chdir("C:\\Users\\hp\\Desktop\\sax_pro")
import numpy as np
from saxpy.znorm import znorm
from saxpy.discord import find_discords_brute_force

# %%
from numpy import genfromtxt
dd = genfromtxt("C:\\Users\\hp\\Desktop\\test-driven-data\\ExpDecayTenWaves.csv", delimiter=',')

# %%
import matplotlib.pyplot as plt
plt.plot(dd)
plt.show()

# %%
discords = find_discords_brute_force(dd[0:400], 100, 4)
discords
# Out:
# [(0, 2.768352373122233e-07),
#  (201, 2.736010114272977e-07),
#  (100, 2.3950934211384843e-07)]

# %%
import matplotlib.pyplot as plt
plt.plot(discords)
plt.show()

# %%
discords[0][0]
# Out:
# 0
